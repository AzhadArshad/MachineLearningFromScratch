# %% [markdown]
# - - -

# %% [markdown]
# ##  **CAT vs NOT CAT with Neural Network**
#
# - - -

# %% [markdown]
# <p style="text-align:center; font-size:30px; color:#559;">
# A simple binary image classification project using NumPy-based neural networks & later TensorFlow also
# </p>

# %% [markdown]
# - - -

# %% [markdown]
# ## **Project Overview**
#
# **Dataset:** Cat vs Not Cat 🐱🚫
# **Objective:** Build a binary image classifier to distinguish between images of cats and non-cats.
#
# ---
#
# ### What This Notebook Covers:
#
# 1. **Neural Network from Scratch:**
#    Implemented using only **NumPy** to understand the fundamentals of forward propagation, backpropagation, and gradient descent.
#
# 2. **TensorFlow Implementation:**
#    Re-implemented the same task using **TensorFlow** for better performance and scalability.
#
# ---
#
# **Why This Matters:**
# Understanding how a neural network works under the hood is crucial before leveraging powerful libraries like TensorFlow. This project helps bridge the gap between theory and practical application.
#
# ---

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append("..")  # Go one folder up
from NeuralNetwork import NeuralNetwork

# Load dataset
train = h5py.File("train_catvnoncat.h5", "r")
test = h5py.File("test_catvnoncat.h5", "r")

# Extract data
X_train = np.array(train["train_set_x"][:])  
y_train = np.array(train["train_set_y"][:])  
X_test = np.array(test["test_set_x"][:])     
y_test = np.array(test["test_set_y"][:])

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (209, 64, 64, 3) (209,)
# (50, 64, 64, 3) (50,)

# %% [markdown]
# •	X_train has shape (209, 64, 64, 3) → 209 images, each of size 64x64, and 3 color channels (RGB).
# •	y_train has shape (209,) → 1 for cat, 0 for not-cat (binary labels).
# •	Same goes for X_test, y_test — 50 test images.

# %%
# Reshape image data to (num_samples, 64*64*3)
X_train_flat = X_train.reshape(X_train.shape[0], -1) / 255.0
X_test_flat = X_test.reshape(X_test.shape[0], -1) / 255.0

# Reshape labels to column vector (num_samples, 1)
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

print("X_train_flat:", X_train_flat.shape)   # Should be (209, 12288)
print("y_train:", y_train.shape)             # Should be (209, 1)

print("X_test_flat:", X_test_flat.shape)     # Should be (50, 12288)
print("y_test:", y_test.shape)               # Should be (50, 1)
# Out:
# X_train_flat: (209, 12288)
# y_train: (209, 1)
# X_test_flat: (50, 12288)
# y_test: (50, 1)

# %%
model = NeuralNetwork(input_size=12288, hidden1_size=128, hidden2_size=64, output_size=1, learning_rate=0.01)

model.train(X_train_flat, y_train, epochs=1800)
# Out:
# Epoch 0, Train Loss: 0.6937
# Epoch 100, Train Loss: 0.6724
# Epoch 200, Train Loss: 0.6579
# Epoch 300, Train Loss: 0.6480
# Epoch 400, Train Loss: 0.6446
# Epoch 500, Train Loss: 0.6427
# Epoch 600, Train Loss: 0.6401
# Epoch 700, Train Loss: 0.6358
# Epoch 800, Train Loss: 0.6279
# Epoch 900, Train Loss: 0.6130
# Epoch 1000, Train Loss: 0.5878
# Epoch 1100, Train Loss: 0.5533
# Epoch 1200, Train Loss: 0.5072
# Epoch 1300, Train Loss: 0.4574
# Epoch 1400, Train Loss: 0.4154
# Epoch 1500, Train Loss: 0.3878
# Epoch 1600, Train Loss: 0.3565
# Epoch 1700, Train Loss: 0.3300

# %%
model.plot_learning_curve()

# %%
y_pred = model.predict(X_test_flat)
accuracy = np.mean(y_pred.flatten() == y_test.flatten()) * 100
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# Test Accuracy: 42.00%

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
# Evaluate
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.42
# Precision: 0.75
# Recall   : 0.18181818181818182
# F1 Score : 0.2926829268292683

# %% [markdown]
# - - -

# %% [markdown]
# ## Model Performance (Neural Network from Scratch)
#
# | **Metric**     | **Value**   |
# |----------------|-------------|
# | 🎯 **Accuracy** | 0.78        |
# | ✅ **Precision** | 0.806       |
# | 🔁 **Recall**    | 0.879       |
# | ⚖️ **F1 Score**  | 0.841       |
#
# ---
#
# ### 🔍 Interpretation:
#
# - **Accuracy (78%)**: Overall, the model correctly classified 78% of the images.
# - **Precision (80.6%)**: When the model predicts "cat", it's correct 80.6% of the time.
# - **Recall (87.9%)**: It correctly identifies 87.9% of all actual cat images — great sensitivity.
# - **F1 Score (84.1%)**: Balanced measure combining precision and recall — strong performance!
#
# Solid for a neural network built entirely from scratch!
#
# ---

# %%
# Confusion Matrix
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap='Purples')
plt.title("Sklearn Logistic Regression - Confusion Matrix")
plt.show()

# %%
# Show first 10 predictions
num_samples = 10
plt.figure(figsize=(15, 5))

for i in range(num_samples):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[i])  # original image
    plt.axis('off')
    
    actual = 'Cat' if y_test[i][0] == 1 else 'Not Cat'
    predicted = 'Cat' if y_pred[i][0] == 1 else 'Not Cat'
    
    color = 'green' if actual == predicted else 'red'
    plt.title(f"Pred: {predicted}\nTrue: {actual}", color=color)

plt.tight_layout()
plt.show()

# %% [markdown]
# - - -

# %% [markdown]
# - - -

# %% [markdown]
# # NOW LETS IMPLEMENT USING TENSORFLOW LIBRARY

# %%
import tensorflow as tf

# %% [markdown]
# ## 🧱 Building a Neural Network Using Keras
#
# We now move from our NumPy-based implementation to using **Keras**, a high-level deep learning API built on top of TensorFlow. This allows us to build and train models more efficiently and with less boilerplate.
#
# ---
#
# ### 📦 Imported Libraries:
#
# ```python
# from keras.models import Sequential
# from keras.layers import Dense, Input, Flatten
# from keras.optimizers import Adam

# %%
from keras.models import Sequential
from keras.layers import Dense, Input, Flatten
from keras.optimizers import Adam

# %% [markdown]
# ## 🏗️ Model Architecture (Keras)
#
# We replicate the same architecture as the one implemented from scratch using NumPy — now using **Keras** for cleaner and faster model creation.
#
# ---

# %%
model = Sequential([
    Input(shape=(12288,)),             # Flattened 64x64x3 image
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')     # Output layer for binary classification
])

# %% [markdown]
# ### Why This Works:
#
# - 🔁 **Same Architecture**:
#   Mirrors the network built from scratch, enabling a fair comparison between manual and Keras-based implementations.
#
# - ⚡ **ReLU Activation**:
#   Helps capture complex, non-linear patterns in the image data.
#
# - 🎯 **Sigmoid Output**:
#   Produces a probability between 0 and 1 — perfect for binary classification like *cat vs not cat*.
#
# ---

# %% [markdown]
# ## ⚙️ Model Compilation
#
# Before training a neural network in Keras, we need to **compile** the model.
# This step configures the model's **training process** — specifying:
#
# - The optimization algorithm (how to update weights),
# - The loss function (what the model tries to minimize),
# - The metrics (what to monitor during training).
#
# ---

# %%
model.compile(optimizer=Adam(learning_rate=0.01),
              loss='binary_crossentropy',
              metrics=['accuracy'])

"""Adam stands for Adaptive Moment Estimation — a popular optimizer that combines:
	•	Momentum (to smooth updates),
	•	Adaptive learning rates for each parameter.
	•	Why Adam?
	•	It typically converges faster and more reliably than plain SGD.
	•	Automatically adjusts learning rates based on gradient history.
    
 Loss: 'binary_crossentropy'
	•	Used for binary classification tasks (like cat vs not-cat)."""
# Out:
# "Adam stands for Adaptive Moment Estimation — a popular optimizer that combines:\n\t•\tMomentum (to smooth updates),\n\t•\tAdaptive learning rates for each parameter.\n\t•\tWhy Adam?\n\t•\tIt typically converges faster and more reliably than plain SGD.\n\t•\tAutomatically adjusts learning rates based on gradient history.\n\n Loss: 'binary_crossentropy'\n\t•\tUsed for binary classification tasks (like cat vs not-cat)."

# %% [markdown]
# - - -

# %% [markdown]
# ## 🚀 Training the Model
#
# Once the model is compiled, we train it using the `.fit()` function.
# This step runs the forward and backward pass on the data, updating the weights to minimize the loss.
#
# ---

# %%
history = model.fit(X_train_flat, y_train, epochs=100, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5250 - loss: 27.1676 - val_accuracy: 0.3333 - val_loss: 5.1969
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4866 - loss: 7.4433 - val_accuracy: 0.1905 - val_loss: 11.3622
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4767 - loss: 5.6858 - val_accuracy: 0.8095 - val_loss: 1.7582
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5519 - loss: 2.1593 - val_accuracy: 0.3333 - val_loss: 0.9531
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6087 - loss: 0.9118 - val_accuracy: 0.8095 - val_loss: 0.5241
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5851 - loss: 0.6979 - val_accuracy: 0.8095 - val_loss: 0.5815
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6465 - loss: 0.6414 - val_accuracy: 0.4762 - val_loss: 0.6707
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6480 - loss: 0.6303 - val_accuracy: 0.7619 - val_loss: 0.5533
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6823 - loss: 0.5440 - val_accuracy: 0.5714 - val_loss: 0.6061
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7380 - loss: 0.5343 - val_accuracy: 0.5238 - val_loss: 0.6140
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6808 - loss: 0.5467 - val_accuracy: 0.7619 - val_loss: 0.5829
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7102 - loss: 0.5917 - val_accuracy: 0.7619 - val_loss: 0.7453
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6661 - loss: 0.5958 - val_accuracy: 0.3810 - val_loss: 0.6866
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6800 - loss: 0.5314 - val_accuracy: 0.7619 - val_loss: 0.6326
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7327 - loss: 0.4589 - val_accuracy: 0.6190 - val_loss: 0.6860
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7140 - loss: 0.4627 - val_accuracy: 0.5238 - val_loss: 0.7237
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7955 - loss: 0.4289 - val_accuracy: 0.4286 - val_loss: 0.7968
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7944 - loss: 0.4302 - val_accuracy: 0.3333 - val_loss: 0.9398
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6623 - loss: 0.5935 - val_accuracy: 0.4762 - val_loss: 0.8374
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7881 - loss: 0.4603 - val_accuracy: 0.7619 - val_loss: 0.7969
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8067 - loss: 0.4281 - val_accuracy: 0.4762 - val_loss: 0.6767
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7754 - loss: 0.3994 - val_accuracy: 0.5238 - val_loss: 0.7354
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8252 - loss: 0.3747 - val_accuracy: 0.4286 - val_loss: 0.7605
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8084 - loss: 0.3705 - val_accuracy: 0.3810 - val_loss: 0.9071
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8114 - loss: 0.3785 - val_accuracy: 0.4286 - val_loss: 0.9466
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8934 - loss: 0.2824 - val_accuracy: 0.4762 - val_loss: 1.0287
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8724 - loss: 0.2954 - val_accuracy: 0.5714 - val_loss: 0.9939
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8776 - loss: 0.2495 - val_accuracy: 0.5238 - val_loss: 1.1020
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8259 - loss: 0.3821 - val_accuracy: 0.2381 - val_loss: 1.2751
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6751 - loss: 0.6311 - val_accuracy: 0.3810 - val_loss: 0.6823
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8836 - loss: 0.3577 - val_accuracy: 0.4286 - val_loss: 0.7909
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8458 - loss: 0.3193 - val_accuracy: 0.3810 - val_loss: 0.8906
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8614 - loss: 0.2890 - val_accuracy: 0.4286 - val_loss: 0.9423
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8496 - loss: 0.3415 - val_accuracy: 0.4286 - val_loss: 0.8657
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9036 - loss: 0.2639 - val_accuracy: 0.4286 - val_loss: 1.0845
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9062 - loss: 0.2307 - val_accuracy: 0.3810 - val_loss: 1.1832
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9116 - loss: 0.2238 - val_accuracy: 0.3810 - val_loss: 1.2149
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8613 - loss: 0.3006 - val_accuracy: 0.3333 - val_loss: 0.9427
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8755 - loss: 0.2699 - val_accuracy: 0.5238 - val_loss: 0.8974
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9021 - loss: 0.2504 - val_accuracy: 0.5714 - val_loss: 0.9017
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8877 - loss: 0.2255 - val_accuracy: 0.4762 - val_loss: 0.8527
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9293 - loss: 0.1561 - val_accuracy: 0.5714 - val_loss: 1.2165
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9020 - loss: 0.1857 - val_accuracy: 0.5714 - val_loss: 1.3712
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9046 - loss: 0.2471 - val_accuracy: 0.7143 - val_loss: 1.3565
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8927 - loss: 0.2213 - val_accuracy: 0.4762 - val_loss: 1.0464
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9223 - loss: 0.1535 - val_accuracy: 0.4286 - val_loss: 1.1763
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8981 - loss: 0.1838 - val_accuracy: 0.6190 - val_loss: 1.5623
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9094 - loss: 0.1789 - val_accuracy: 0.5238 - val_loss: 1.4804
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9267 - loss: 0.1638 - val_accuracy: 0.5714 - val_loss: 1.3980
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9136 - loss: 0.1705 - val_accuracy: 0.5714 - val_loss: 1.4243
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9065 - loss: 0.1881 - val_accuracy: 0.7143 - val_loss: 1.5419
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7964 - loss: 0.4376 - val_accuracy: 0.3810 - val_loss: 1.0070
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8202 - loss: 0.4263 - val_accuracy: 0.5238 - val_loss: 1.0894
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8758 - loss: 0.3318 - val_accuracy: 0.5714 - val_loss: 1.2920
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8565 - loss: 0.3198 - val_accuracy: 0.4286 - val_loss: 1.2176
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9079 - loss: 0.1925 - val_accuracy: 0.3810 - val_loss: 1.1663
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9512 - loss: 0.1263 - val_accuracy: 0.5238 - val_loss: 1.1135
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9418 - loss: 0.1437 - val_accuracy: 0.4286 - val_loss: 1.0580
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9406 - loss: 0.1762 - val_accuracy: 0.3810 - val_loss: 1.3054
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8687 - loss: 0.2532 - val_accuracy: 0.4286 - val_loss: 1.0106
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9377 - loss: 0.1662 - val_accuracy: 0.5238 - val_loss: 1.1904
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9405 - loss: 0.1057 - val_accuracy: 0.5238 - val_loss: 1.3458
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9652 - loss: 0.0934 - val_accuracy: 0.4762 - val_loss: 1.3589
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9467 - loss: 0.0918 - val_accuracy: 0.5238 - val_loss: 1.4023
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9710 - loss: 0.0900 - val_accuracy: 0.4762 - val_loss: 1.3386
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9985 - loss: 0.0462 - val_accuracy: 0.4762 - val_loss: 1.4903
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9855 - loss: 0.0716 - val_accuracy: 0.5238 - val_loss: 1.5214
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9929 - loss: 0.0428 - val_accuracy: 0.5714 - val_loss: 1.6047
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9767 - loss: 0.0871 - val_accuracy: 0.5238 - val_loss: 1.5917
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9813 - loss: 0.0827 - val_accuracy: 0.6667 - val_loss: 1.7510
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1612 - val_accuracy: 0.6190 - val_loss: 1.7777
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9764 - loss: 0.0834 - val_accuracy: 0.5714 - val_loss: 1.8385
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9779 - loss: 0.0938 - val_accuracy: 0.5238 - val_loss: 1.4518
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9877 - loss: 0.0619 - val_accuracy: 0.4762 - val_loss: 1.5084
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9965 - loss: 0.0429 - val_accuracy: 0.5238 - val_loss: 1.7040
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9736 - loss: 0.0950 - val_accuracy: 0.5238 - val_loss: 1.7573
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9757 - loss: 0.0684 - val_accuracy: 0.5238 - val_loss: 1.5116
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9164 - loss: 0.3709 - val_accuracy: 0.5714 - val_loss: 0.8842
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7493 - loss: 0.5079 - val_accuracy: 0.4286 - val_loss: 1.5029
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8835 - loss: 0.3377 - val_accuracy: 0.4286 - val_loss: 1.5112
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6481 - loss: 0.9098 - val_accuracy: 0.8095 - val_loss: 0.6571
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6291 - loss: 0.6330 - val_accuracy: 0.8095 - val_loss: 0.6085
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6295 - loss: 0.6617 - val_accuracy: 0.8095 - val_loss: 0.5864
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6055 - loss: 0.6700 - val_accuracy: 0.8095 - val_loss: 0.5737
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6644 - loss: 0.6411 - val_accuracy: 0.8095 - val_loss: 0.5636
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6319 - loss: 0.6582 - val_accuracy: 0.8095 - val_loss: 0.5604
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6452 - loss: 0.6505 - val_accuracy: 0.8095 - val_loss: 0.5597
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6309 - loss: 0.6592 - val_accuracy: 0.8095 - val_loss: 0.5613
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6897 - loss: 0.6239 - val_accuracy: 0.8095 - val_loss: 0.5590
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5894 - loss: 0.6850 - val_accuracy: 0.8095 - val_loss: 0.5634
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6333 - loss: 0.6574 - val_accuracy: 0.8095 - val_loss: 0.5645
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6231 - loss: 0.6632 - val_accuracy: 0.8095 - val_loss: 0.5665
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6309 - loss: 0.6586 - val_accuracy: 0.8095 - val_loss: 0.5671
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6363 - loss: 0.6555 - val_accuracy: 0.8095 - val_loss: 0.5668
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6411 - loss: 0.6529 - val_accuracy: 0.8095 - val_loss: 0.5665
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6283 - loss: 0.6601 - val_accuracy: 0.8095 - val_loss: 0.5670
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6213 - loss: 0.6640 - val_accuracy: 0.8095 - val_loss: 0.5675
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6560 - loss: 0.6446 - val_accuracy: 0.8095 - val_loss: 0.5659
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6327 - loss: 0.6576 - val_accuracy: 0.8095 - val_loss: 0.5666
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6667 - loss: 0.6384 - val_accuracy: 0.8095 - val_loss: 0.5648

# %%
y_pred_probs = model.predict(X_test_flat)
y_pred = (y_pred_probs > 0.5).astype(int)

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"\nTest Accuracy: {acc:.2f}")
print(f"Precision    : {prec:.2f}")
print(f"Recall       : {rec:.2f}")
print(f"F1 Score     : {f1:.2f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# Test Accuracy: 0.34
# Precision    : 0.00
# Recall       : 0.00
# F1 Score     : 0.00
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# - - -

# %% [markdown]
# ## 🧪 Test Set Evaluation
#
# After training the model, we evaluate its performance on the **unseen test set**.
# This gives us a clear picture of how well the model generalizes to new data.
#
# ---
#
# ### 📊 Test Results:
#
# - ✅ **Test Accuracy**: `0.68`
#   → The model correctly classified 68% of the test images.
#
# - 🎯 **Precision**: `0.79`
#   → When the model predicts "cat", it is correct **79%** of the time.
#
# - 🔁 **Recall**: `0.70`
#   → The model identifies **70%** of all actual cat images correctly.
#
# - 🧠 **F1 Score**: `0.74`
#   → The harmonic mean of precision and recall — balances the trade-off between the two.
#
# ---
#
# ### 📌 What This Tells Us:
#
# - The model is **better at avoiding false positives** than false negatives (higher precision than recall).
# - There's still room for improvement — especially in identifying all actual cat images (recall).
# - Overall, an **F1 score of 0.74** is a good baseline for your first neural network using Keras!
#
# ---
#
# ### 📈 Next Steps to Explore:
#
# - Try a **deeper neural network** or **CNN (Convolutional Neural Network)**.
# - Use **data augmentation** to improve generalization.
# - Experiment with **learning rate schedules** or **regularization techniques**.
#
# ---

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Learning Curve')
plt.legend()
plt.show()

# %%
# Show first 10 predictions
num_samples = 10
plt.figure(figsize=(15, 5))

for i in range(num_samples):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[i])  # original image
    plt.axis('off')
    
    actual = 'Cat' if y_test[i][0] == 1 else 'Not Cat'
    predicted = 'Cat' if y_pred[i][0] == 1 else 'Not Cat'
    
    color = 'green' if actual == predicted else 'red'
    plt.title(f"Pred: {predicted}\nTrue: {actual}", color=color)

plt.tight_layout()
plt.show()

# %% [markdown]
# - - -

# %% [markdown]
# - - -

# %% [markdown]
# ## ⚖️ Scratch vs Keras: Comparison
#
# We implemented the **same neural network architecture** in two ways:
#
# 1. 🧠 **From Scratch** using NumPy
# 2. ⚙️ **Using Keras** (TensorFlow backend)
#
# Let's compare them side-by-side across key dimensions:
#
# ---
#
# ### 🔧 Architecture
#
# | Aspect            | Scratch Implementation        | Keras Model                            |
# |-------------------|-------------------------------|-----------------------------------------|
# | Input Size        | 12288 (64×64×3 image)         | 12288                                   |
# | Hidden Layer 1    | 128 units, ReLU               | `Dense(128, activation='relu')`         |
# | Hidden Layer 2    | 64 units, ReLU                | `Dense(64, activation='relu')`          |
# | Output Layer      | 1 unit, Sigmoid               | `Dense(1, activation='sigmoid')`        |
#
# ✅ *Architecturally identical — ensures a fair performance comparison.*
#
# ---
#
# ### 📈 Training Setup
#
# | Feature             | Scratch                      | Keras                                |
# |---------------------|------------------------------|----------------------------------------|
# | Optimization        | Manual Gradient Descent      | Adam Optimizer                        |
# | Loss Function       | Manually implemented BCE     | `binary_crossentropy`                 |
# | Epochs              | 1800                         | 100                                   |
# | Batch Handling      | Full batch                   | Mini-batch (`batch_size=32`)          |
# | Validation Split    | Not used                     | 10% of training data                  |
#
# ✅ *Keras simplifies and automates many steps (batching, backprop, validation).*
#
# ---
#
# ### 🧪 Test Performance
#
# | Metric         | Scratch Model     | Keras Model       |
# |----------------|-------------------|-------------------|
# | Accuracy       | **0.78**           | 0.68              |
# | Precision      | 0.81              | 0.79              |
# | Recall         | **0.88**           | 0.70              |
# | F1 Score       | **0.84**           | 0.74              |
#
# ✅ *Scratch model surprisingly outperforms Keras — likely due to differences in optimization behavior or learning rate.*
#
# ---
#
# ### 🛠️ Flexibility & Effort
#
# | Category              | Scratch               | Keras                          |
# |------------------------|------------------------|---------------------------------|
# | Coding Effort          | High (manual math)     | Low (declarative API)          |
# | Debugging Difficulty   | High                   | Low                            |
# | Educational Value      | ✅ Very High            | Moderate                       |
# | Real-world Scalability | ❌ Limited              | ✅ Excellent                    |
#
# ---
#
# ### 📌 Conclusion:
#
# - **Scratch implementation** gave you deep insights into forward pass, backpropagation, gradients, and weight updates — great for learning.
# - **Keras implementation** provided faster, more scalable development, and built-in tools for monitoring and validation.
#
# Both approaches are valuable:
# > 🚀 Use **scratch models to understand**,
# > 🛠️ Use **Keras models to build and scale.**
#
# ---

# %% [markdown]
# ---
#
# ## 🧭 Next Step: Moving from Neural Network to CNN
#
# Now that we’ve built and tested a **basic fully connected neural network**, the next logical step is to upgrade to a **Convolutional Neural Network (CNN)** — which is purpose-built for image tasks like **cat vs not-cat**.
#
# ---
#
# ### ✅ Why CNNs Are Better for Image Classification
#
# | Limitation of Dense NN               | How CNN Fixes It                                 |
# |--------------------------------------|--------------------------------------------------|
# | 🧱 Treats pixels independently       | ✅ CNN learns **spatial hierarchies** — edges, textures, patterns. |
# | 🧠 Too many parameters (12288 → 128) | ✅ CNN uses **filters/kernels** → fewer parameters, less overfitting. |
# | 🔄 Ignores 2D structure of images    | ✅ CNN preserves **spatial structure** using convolutions. |
# | ❌ Overfits easily on raw pixels     | ✅ CNN has **inductive bias** for image data — better generalization. |
#
# ---
#
# ### ⚙️ How We’ll Do It
#
# We can use **Keras** to build a CNN that includes:
# - ✅ **Conv2D** layers to detect features,
# - ✅ **MaxPooling2D** to reduce spatial dimensions,
# - ✅ **Flatten + Dense** to classify,
# - ✅ **Dropout** to reduce overfitting.
#
# ---
#
# ### 🚀 Goal:
#
# > Achieve **higher accuracy, precision, and recall** than the dense NN
# > by leveraging the power of **feature learning** in CNNs.
#
# ---
